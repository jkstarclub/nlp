# %% [markdown]
# <a href="https://colab.research.google.com/github/crow-intelligence/gettingStartedWithColab/blob/main/02_Using_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Milestone
#
# ## Tensor
#
# ### Load the data
#
# Let's load the vectorized training and test data from Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import string

# Load raw data

texts = []
labels = []
with open("/content/drive/My Drive/Colab Notebooks/hamsms.txt", "r") as infile:
  for l in infile:
    label, text = l.strip().split("\t")
    if label == "ham":
      labels.append(0)
    else:
      labels.append(1)
    text = "".join([ch.lower() for ch in text if ch not in string.punctuation])
    texts.append(text)

labels = np.asarray(labels)

# %% [markdown]
# ### Preprocess data

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split


tokenizer = Tokenizer(num_words=5000) # voccab size is 9661 -> 5000 should be enough
tokenizer.fit_on_texts(texts)

X_train_raw, X_test_raw, y_train, y_test = train_test_split(texts, labels, random_state=42)

X_train_emb = tokenizer.texts_to_sequences(X_train_raw)
X_test_emb = tokenizer.texts_to_sequences(X_test_raw)

vocab_size = len(tokenizer.word_index) + 1

# print(sum([len(e) for e in texts])/len(texts)) -> 76.25008970218873, 100 should be enough for maxlen

maxlen = 100

X_train = pad_sequences(X_train_emb, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test_emb, padding='post', maxlen=maxlen)

# %% [markdown]
# ### A very simple Neural Network

# %%
import keras
import tensorflow as tf

embedding_dim = 50
model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size,embedding_dim))
model.add(keras.layers.GlobalMaxPool1D())
model.add(keras.layers.Dense(16, activation=tf.nn.relu))
model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])
model.summary()

# Create a callback that saves the model's weights

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/checkpoints/weights.{epoch:02d}-{val_loss:.2f}.ckpt",
                                                 save_weights_only=True,
                                                 verbose=1)
model.fit(X_train, y_train,
          epochs=100,
          verbose=False,
          validation_data=(X_test, y_test),
          batch_size=16,
          callbacks=[cp_callback])
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
model.save("/content/drive/My Drive/Colab Notebooks/TFmodel")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 50)          483100
#
#  global_max_pooling1d (Globa  (None, 50)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 16)                816
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 483,933
# Trainable params: 483,933
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.01-0.32.ckpt
#
# Epoch 2: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.02-0.17.ckpt
#
# Epoch 3: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.03-0.10.ckpt
#
# Epoch 4: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.04-0.08.ckpt
#
# Epoch 5: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.05-0.07.ckpt
#
# Epoch 6: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.06-0.07.ckpt
#
# Epoch 7: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.07-0.07.ckpt
#
# Epoch 8: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.08-0.07.ckpt
#
# Epoch 9: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.09-0.07.ckpt
#
# Epoch 10: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.10-0.07.ckpt
#
# Epoch 11: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.11-0.08.ckpt
#
# Epoch 12: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.12-0.08.ckpt
#
# Epoch 13: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.13-0.08.ckpt
#
# Epoch 14: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.14-0.08.ckpt
#
# Epoch 15: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.15-0.08.ckpt
#
# Epoch 16: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.16-0.08.ckpt
#
# Epoch 17: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.17-0.09.ckpt
#
# Epoch 18: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.18-0.09.ckpt
#
# Epoch 19: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.19-0.09.ckpt
#
# Epoch 20: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.20-0.09.ckpt
#
# Epoch 21: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.21-0.09.ckpt
#
# Epoch 22: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.22-0.09.ckpt
#
# Epoch 23: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.23-0.09.ckpt
#
# Epoch 24: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.24-0.09.ckpt
#
# Epoch 25: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.25-0.09.ckpt
#
# Epoch 26: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.26-0.09.ckpt
#
# Epoch 27: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.27-0.09.ckpt
#
# Epoch 28: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.28-0.09.ckpt
#
# Epoch 29: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.29-0.10.ckpt
#
# Epoch 30: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.30-0.10.ckpt
#
# Epoch 31: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.31-0.10.ckpt
#
# Epoch 32: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.32-0.10.ckpt
#
# Epoch 33: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.33-0.10.ckpt
#
# Epoch 34: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.34-0.10.ckpt
#
# Epoch 35: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.35-0.10.ckpt
#
# Epoch 36: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.36-0.10.ckpt
#
# Epoch 37: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.37-0.10.ckpt
#
# Epoch 38: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.38-0.10.ckpt
#
# Epoch 39: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.39-0.10.ckpt
#
# Epoch 40: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.40-0.10.ckpt
#
# Epoch 41: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.41-0.10.ckpt
#
# Epoch 42: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.42-0.10.ckpt
#
# Epoch 43: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.43-0.10.ckpt
#
# Epoch 44: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.44-0.10.ckpt
#
# Epoch 45: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.45-0.10.ckpt
#
# Epoch 46: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.46-0.10.ckpt
#
# Epoch 47: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.47-0.10.ckpt
#
# Epoch 48: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.48-0.10.ckpt
#
# Epoch 49: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.49-0.11.ckpt
#
# Epoch 50: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.50-0.11.ckpt
#
# Epoch 51: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.51-0.11.ckpt
#
# Epoch 52: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.52-0.11.ckpt
#
# Epoch 53: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.53-0.11.ckpt
#
# Epoch 54: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.54-0.11.ckpt
#
# Epoch 55: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.55-0.11.ckpt
#
# Epoch 56: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.56-0.11.ckpt
#
# Epoch 57: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.57-0.11.ckpt
#
# Epoch 58: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.58-0.11.ckpt
#
# Epoch 59: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.59-0.11.ckpt
#
# Epoch 60: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.60-0.11.ckpt
#
# Epoch 61: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.61-0.11.ckpt
#
# Epoch 62: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.62-0.11.ckpt
#
# Epoch 63: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.63-0.11.ckpt
#
# Epoch 64: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.64-0.12.ckpt
#
# Epoch 65: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.65-0.12.ckpt
#
# Epoch 66: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.66-0.11.ckpt
#
# Epoch 67: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.67-0.12.ckpt
#
# Epoch 68: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.68-0.12.ckpt
#
# Epoch 69: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.69-0.11.ckpt
#
# Epoch 70: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.70-0.12.ckpt
#
# Epoch 71: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.71-0.12.ckpt
#
# Epoch 72: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.72-0.11.ckpt
#
# Epoch 73: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.73-0.12.ckpt
#
# Epoch 74: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.74-0.12.ckpt
#
# Epoch 75: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.75-0.12.ckpt
#
# Epoch 76: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.76-0.12.ckpt
#
# Epoch 77: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.77-0.12.ckpt
#
# Epoch 78: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.78-0.12.ckpt
#
# Epoch 79: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.79-0.12.ckpt
#
# Epoch 80: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.80-0.12.ckpt
#
# Epoch 81: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.81-0.12.ckpt
#
# Epoch 82: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.82-0.12.ckpt
#
# Epoch 83: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.83-0.12.ckpt
#
# Epoch 84: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.84-0.12.ckpt
#
# Epoch 85: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.85-0.12.ckpt
#
# Epoch 86: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.86-0.12.ckpt
#
# Epoch 87: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.87-0.12.ckpt
#
# Epoch 88: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.88-0.12.ckpt
#
# Epoch 89: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.89-0.12.ckpt
#
# Epoch 90: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.90-0.12.ckpt
#
# Epoch 91: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.91-0.12.ckpt
#
# Epoch 92: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.92-0.12.ckpt
#
# Epoch 93: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.93-0.12.ckpt
#
# Epoch 94: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.94-0.12.ckpt
#
# Epoch 95: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.95-0.12.ckpt
#
# Epoch 96: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.96-0.12.ckpt
#
# Epoch 97: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.97-0.12.ckpt
#
# Epoch 98: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.98-0.12.ckpt
#
# Epoch 99: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.99-0.12.ckpt
#
# Epoch 100: saving model to /content/drive/My Drive/Colab Notebooks/checkpoints/weights.100-0.12.ckpt
# Training Accuracy: 0.9998
# Testing Accuracy:  0.9785

# %%
from sklearn.metrics import classification_report

y_pred = (model.predict(X_test) > 0.5).astype("int32")
y_pred = [e[0] for e in y_pred]

print(classification_report(y_test, y_pred))
# Out:
# 44/44 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1203
#            1       0.92      0.93      0.92       191
#
#     accuracy                           0.98      1394
#    macro avg       0.95      0.96      0.95      1394
# weighted avg       0.98      0.98      0.98      1394
